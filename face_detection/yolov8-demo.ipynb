# %% [markdown]
# # Demo of YOLO pretrained model on faces
#
# References:
# https://docs.ultralytics.com/tasks/detect/#predict
# https://docs.ultralytics.com/modes/predict/
# https://github.com/akanametov/yolov8-face

# %% [markdown]
# We test the pretrained face model from: https://github.com/akanametov/yolov8-face
#
# Download the model and place it in a folder:
# ```pretrained_models```

# %%
from ultralytics import YOLO
from PIL import Image

model = YOLO("./pretrained_models/yolov8n-face.pt")

# %%
# Run batched inference on a list of images
results = model('https://ultralytics.com/images/bus.jpg')  # return a list of Results objects
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 d:\Programming\cybertruck\face_detection\bus.jpg: 640x480 2 faces, 79.0ms
# Speed: 6.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)

# %% [markdown]
# ### Results objects have the following useful information:
#
# ```
# for result in results:
#     boxes = result.boxes  # Boxes object for bbox outputs
#     masks = result.masks  # Masks object for segmentation masks outputs
#     keypoints = result.keypoints  # Keypoints object for pose outputs
#     probs = result.probs  # Probs object for classification outputs
# ```
#
# We can also get other useful info like inference speed, original image shape, etc:
# https://docs.ultralytics.com/modes/predict/#working-with-results

# %%
from IPython.display import display

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    #im.show()  # show image
    # im.save('results.jpg')  # save image
    display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=810x1080>
