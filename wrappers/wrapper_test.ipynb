# %%
import sys
sys.path.append('D:\Programming\cybertruck')

# %%
from face_wrapper import Face_Inference_Wrapper
from cnn.face_cnn import Face_CNN

# %%
cnn = Face_CNN(args=None)
model = Face_Inference_Wrapper(cnn)
# Out:
# {'model_name': 'resnet50', 'weights': 'ResNet50_Weights.IMAGENET1K_V2', 'freeze': False}
# Using cache found in C:\Users\robin/.cache\torch\hub\pytorch_vision_main
# Using cache found in C:\Users\robin/.cache\torch\hub\pytorch_vision_main
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to C:\Users\robin/.cache\torch\hub\checkpoints\resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:04<00:00, 24.0MB/s]

# %%
import torch

x = torch.rand((1, 3, 224, 224))

# %%
Face_Inference_Wrapper(x)
# Out:
# Face_Inference_Wrapper(
#   (detector): YOLO(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): C2f(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
# ...
